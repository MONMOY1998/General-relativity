# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# Sample data for density (rhos) and pressure (Ps)
rhos = np.array([1, 2, 3, 4, 5])
Ps = np.array([2, 3, 5, 7, 11])

# %%
# Pressure as a function of density
cPs = CubicSpline(rhos, Ps)

# Density as a function of pressure
crhos = CubicSpline(Ps, rhos)

# %%
# Interpolated values
rhos_values = np.linspace(min(rhos), max(rhos), 100)
Ps_values = cPs(rhos_values)

Ps_values1 = np.linspace(min(Ps), max(Ps), 100)
rhos_values1 = crhos(Ps_values1)

# %%
# Plot Pressure as a function of Density
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(rhos, Ps, 'o', label='Original data')
plt.plot(rhos_values, Ps_values, '-', label='Cubic spline')
plt.xlabel('Density (rhos)')
plt.ylabel('Pressure (Ps)')
plt.title('Pressure as a function of Density')
plt.legend()

# Plot Density as a function of Pressure
plt.subplot(1, 2, 2)
plt.plot(Ps, rhos, 'o', label='Original data')
plt.plot(Ps_values1, rhos_values1, '-', label='Cubic spline')
plt.xlabel('Pressure (Ps)')
plt.ylabel('Density (rhos)')
plt.title('Density as a function of Pressure')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.interpolate import CubicSpline

# Sample data
rhos_sample = np.array([1, 2, 3, 4, 5])
Ps_sample = np.array([2, 3, 5, 7, 11])

# Create cubic spline interpolators
cPs = CubicSpline(rhos_sample, Ps_sample)
crhos = CubicSpline(Ps_sample, rhos_sample)

# %%
x = np.array([1.0, 0.5, 3.0])  # [r, m, P]

# %%
def f(x):
    r = x[0]
    m = x[1]
    P = x[2]
    
    rho = crhos(P)
    
    dr_dr = 1
    dm_dr = 4 * np.pi * (r**2) * rho
    dP_dr = -((m * rho) / (r**2)) * (1 + (P / rho)) * (1 + ((4 * np.pi * P * (r**3)) / m)) * ((1 - ((2 * m) / r))**(-1))
    dphi_dr = (-dP_dr) / (rho * (1 + (P / rho)))
    
    return np.array([dr_dr, dm_dr, dP_dr, dphi_dr])

derivatives = f(x)
print("Derivatives:", derivatives)
# Out:
# Derivatives: [ 1.         25.13274123        -inf         inf]
# C:\Users\User\AppData\Local\Temp\ipykernel_9432\8903593.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   dP_dr = -((m * rho) / (r**2)) * (1 + (P / rho)) * (1 + ((4 * np.pi * P * (r**3)) / m)) * ((1 - ((2 * m) / r))**(-1))

# %%
# Example state array
x = [1.0, 0.5, 3.0]  # [r, m, P]

# Extracting individual components
r = x[0]  # r = 1.0
m = x[1]  # m = 0.5
P = x[2]  # P = 3.0

print(f"Radius (r): {r}")
print(f"Mass (m): {m}")
print(f"Pressure (P): {P}")
# Out:
# Radius (r): 1.0
# Mass (m): 0.5
# Pressure (P): 3.0

# %%
import numpy as np

# Example values for the derivatives
dr_dr = 1
dm_dr = 0.1  # Example value for dm_dr
dP_dr = -0.05  # Example value for dP_dr
dphi_dr = -0.02  # Example value for dphi_dr

# Create a NumPy array with these values
derivatives = np.array([dr_dr, dm_dr, dP_dr, dphi_dr])

print("Derivatives array:", derivatives)
# Out:
# Derivatives array: [ 1.    0.1  -0.05 -0.02]

# %%
import numpy as np
from scipy.interpolate import CubicSpline

# Sample data
rhos_sample = np.array([1, 2, 3, 4, 5])
Ps_sample = np.array([2, 3, 5, 7, 11])

# Create cubic spline interpolators
cPs = CubicSpline(rhos_sample, Ps_sample)
crhos = CubicSpline(Ps_sample, rhos_sample)

# %%
x = np.array([1.0, 0.5, 3.0, 0.1])  # [r, m, P, phi]
y = np.array([0.01, 0.02])  # [J, w]

# %%
def f2(x, y):
    r = x[0]
    m = x[1]
    P = x[2]
    phi = x[3]
    J = y[0]
    w = y[1]
    
    rho = crhos(P)
    
    dJ_dr = (((8. * np.pi) / 3.) * (r**4) * (rho + P) * w * (np.exp(-phi))) / (np.sqrt(1 - (2 * m / r)))
    dw_dr = (6 * np.exp(phi) * J) / ((r**4) * (np.sqrt(1 - (2 * m) / r)))
    
    return np.array([dJ_dr, dw_dr])

derivatives = f2(x, y)
print("Derivatives:", derivatives)
# Out:
# Derivatives: [inf inf]
# C:\Users\User\AppData\Local\Temp\ipykernel_9432\1804487622.py:11: RuntimeWarning: divide by zero encountered in double_scalars
#   dJ_dr = (((8. * np.pi) / 3.) * (r**4) * (rho + P) * w * (np.exp(-phi))) / (np.sqrt(1 - (2 * m / r)))
# C:\Users\User\AppData\Local\Temp\ipykernel_9432\1804487622.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   dw_dr = (6 * np.exp(phi) * J) / ((r**4) * (np.sqrt(1 - (2 * m) / r)))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

global G,c
G=6.67e-8
c=3e10

#Interpolating the EOS

file_path = "D:\\DEBADES SIR;S PAPERS\\Slowly rotating neutron star\\SLy.txt"

sly=np.genfromtxt(file_path,delimiter='')
nbs=sly[:,1]
rhos=sly[:,2]
Ps=sly[:,3]

cPs=CubicSpline(rhos,Ps)
crs=CubicSpline(Ps,rhos)
cns=CubicSpline(Ps,nbs)


fps=np.genfromtxt("D:\\DEBADES SIR;S PAPERS\\Slowly rotating neutron star\\FPS.txt",delimiter="    ")
nbf=fps[:,1]
rhof=fps[:,2]
Pf=fps[:,3]

cPf=CubicSpline(rhof,Pf)
crf=CubicSpline(Pf,rhof)
cnf=CubicSpline(Pf,nbf)


apr=np.genfromtxt("D:\\DEBADES SIR;S PAPERS\\Slowly rotating neutron star\\apr.txt", delimiter="  ")
nba=apr[:,0]*1e14*c*c
rhoa=apr[:,1]*1e14
Pa=apr[:,2]*1e14*c*c

cPa=CubicSpline(rhoa,Pa)
cra=CubicSpline(Pa,rhoa)
cna=CubicSpline(Pa,nba)

def f(x,bool):
    r=x[0]
    m=x[1]
    P=x[2]
    if(bool==0):
        rho=crs(P)
    elif(bool==1):
        rho=crf(P)
    elif(bool==2):
        rho=cra(P)
    dr_dr=1
    dm_dr=4.*np.pi*(r**2)*rho
    dP_dr=-(((G*m*rho)/(r**2))*(1+(P/(rho*c*c)))*(1+((4*np.pi*P*(r**3))/(m*c*c))))/(1-((2*G*m)/(r*c*c)))
    dphi_dr=(-dP_dr)/((rho*c*c)*(1+(P/(rho*c*c))))

    return np.array([dr_dr, dm_dr, dP_dr, dphi_dr])
    
def f2(x,y,bool):
    r=x[0]
    M=x[1]
    P=x[2]
    phi=x[3]
    j=y[0]
    w=y[1]
    
    if(bool==0):
        rho=crs(P)
    elif(bool==1):
        rho=crf(P)
    elif(bool==2):
        rho=cra(P)
    dj_dr=(((8.*np.pi)/3.)*(r**4)*(rho+(P/(c**2)))*w*(np.exp(-phi)))*(np.sqrt(1-(2*G*M)/(r*c*c)))
    
    dw_dr=(G*np.exp(phi)*j)/(c*c*(r**4)*(np.sqrt(1-(2*G*M)/(r*c*c))))
    
    return np.array([dj_dr,dw_dr])

def ns_solve(w_0,bool):
#Initial Conditions
    rho_0=1e15
    dr=500 #In cm
    if(bool==0):
        P_0=cPs(rho_0)
    elif(bool==1):
        P_0=cPf(rho_0)
    elif(bool==2):
        P_0=cPa(rho_0)
    X=np.zeros([4,80000])
    X[:,0]=np.array([500,1,P_0,0.001])

    #Solve using RK4
    for i in range(1,80000):
        k1=f(X[:,i-1],bool)
        k2=f(X[:,i-1]+k1*0.5*dr,bool)
        k3=f(X[:,i-1]+k2*0.5*dr,bool)
        k4=f(X[:,i-1]+k3*dr,bool)
    
        X[:,i]=X[:,i-1]+(dr*(k1+2*k2+2*k3+k4))/6.
        
        if((X[2,i]/P_0)<1e-10):
            break

    #for j in range(i,80000):
        #X=np.delete(X,i,1)
    
    alpha=X[3,i-1]
    k=(0.5*np.log(1-((2*G*X[1,i-1])/(X[0,i-1]*c*c))))/alpha
    X[3,]=X[3,]*k
        
    Y=np.zeros([2,i])
    Y[:,0]=np.array([0.001,w_0])
    
    for j in range(1,i):
        k_1=f2(X[:,j-1],Y[:,j-1],bool)
        k_2=f2(X[:,j-1],Y[:,j-1]+k_1*0.5*dr,bool)
        k_3=f2(X[:,j-1],Y[:,j-1]+k_2*0.5*dr,bool)
        k_4=f2(X[:,j-1],Y[:,j-1]+k_3*dr,bool)
        
        Y[:,j]=Y[:,j-1]+(dr*(k_1+2*k_2+2*k_3+k_4))/6.
    
    
    Y[1,i-1]=Y[1,i-1]+((2*G*Y[0,i-1])/((c**2)*(X[0,i-1]**3)))
    return X[:,i-1],Y[:,i-1]

w=np.linspace(1.,100.,100)

res_s1=np.zeros([4,len(w)])
res_f1=np.zeros([4,len(w)])
res_a1=np.zeros([4,len(w)])

res_s2=np.zeros([2,len(w)])
res_f2=np.zeros([2,len(w)])
res_a2=np.zeros([2,len(w)])

for i in range(len(w)):
    res_s1[:,i],res_s2[:,i]=ns_solve(w[i],0)
    res_f1[:,i],res_f2[:,i]=ns_solve(w[i],1)
    res_a1[:,i],res_a2[:,i]=ns_solve(w[i],2)
    #print(i)


w_s=res_s2[1,]
w_f=res_f2[1,]
w_a=res_a2[1,]

J_s=res_s2[0,]
J_f=res_f2[0,]
J_a=res_a2[0,]

I_s=np.divide(J_s,w_s)
I_f=np.divide(J_f,w_f)
I_a=np.divide(J_a,w_a)


plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: MOI vs Central Spin")
ax.set_ylabel(r"Moment of Inertia $[g\,cm^2]$")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,I_s,'r--',label="SLy EoS")
plt.plot(w,I_f,'b--',label="FPS EoS")
plt.plot(w,I_a,'g--',label="APR EoS")
plt.text(10,0.85e45,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("MoIvsw_SRot.png")


plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: Observed vs Central Spin")
ax.set_ylabel(r"$\Omega_{obs}$ [$rot/sec$]")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,w_s,'r--',label="SLy EoS")
plt.plot(w,w_f,'b--',label="FPS EoS")
plt.plot(w,w_a,'g--',label="APR EoS")
plt.text(60,20,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("wvsw_SRot.png")
plt.close()

plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: J vs Central Spin")
ax.set_ylabel(r"J [$g\,cm^2/sec$]")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,J_s,'r--',label="SLy EoS")
plt.plot(w,J_f,'b--',label="FPS EoS")
plt.plot(w,J_a,'g--',label="APR EoS")
plt.text(60,0.2e47,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("Jvsw_SRot.png")
plt.close()

# %%
print(I_s)
# Out:
# [9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44
#  9.78859883e+44 9.78859883e+44 9.78859883e+44 9.78859883e+44]

# %%
print(J_s)
# Out:
# [1.14670093e+45 2.29340186e+45 3.44010279e+45 4.58680372e+45
#  5.73350465e+45 6.88020558e+45 8.02690652e+45 9.17360745e+45
#  1.03203084e+46 1.14670093e+46 1.26137102e+46 1.37604112e+46
#  1.49071121e+46 1.60538130e+46 1.72005140e+46 1.83472149e+46
#  1.94939158e+46 2.06406168e+46 2.17873177e+46 2.29340186e+46
#  2.40807195e+46 2.52274205e+46 2.63741214e+46 2.75208223e+46
#  2.86675233e+46 2.98142242e+46 3.09609251e+46 3.21076261e+46
#  3.32543270e+46 3.44010279e+46 3.55477289e+46 3.66944298e+46
#  3.78411307e+46 3.89878316e+46 4.01345326e+46 4.12812335e+46
#  4.24279344e+46 4.35746354e+46 4.47213363e+46 4.58680372e+46
#  4.70147382e+46 4.81614391e+46 4.93081400e+46 5.04548410e+46
#  5.16015419e+46 5.27482428e+46 5.38949437e+46 5.50416447e+46
#  5.61883456e+46 5.73350465e+46 5.84817475e+46 5.96284484e+46
#  6.07751493e+46 6.19218503e+46 6.30685512e+46 6.42152521e+46
#  6.53619531e+46 6.65086540e+46 6.76553549e+46 6.88020558e+46
#  6.99487568e+46 7.10954577e+46 7.22421586e+46 7.33888596e+46
#  7.45355605e+46 7.56822614e+46 7.68289624e+46 7.79756633e+46
#  7.91223642e+46 8.02690652e+46 8.14157661e+46 8.25624670e+46
#  8.37091679e+46 8.48558689e+46 8.60025698e+46 8.71492707e+46
#  8.82959717e+46 8.94426726e+46 9.05893735e+46 9.17360745e+46
#  9.28827754e+46 9.40294763e+46 9.51761773e+46 9.63228782e+46
#  9.74695791e+46 9.86162800e+46 9.97629810e+46 1.00909682e+47
#  1.02056383e+47 1.03203084e+47 1.04349785e+47 1.05496486e+47
#  1.06643187e+47 1.07789887e+47 1.08936588e+47 1.10083289e+47
#  1.11229990e+47 1.12376691e+47 1.13523392e+47 1.14670093e+47]

# %%
plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: MOI vs Central Spin")
ax.set_ylabel(r"Moment of Inertia $[g\,cm^2]$")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,I_s,'r--',label="SLy EoS")
plt.plot(w,I_f,'b--',label="FPS EoS")
plt.plot(w,I_a,'g--',label="APR EoS")
plt.text(10,0.85e45,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("MoIvsw_SRot.png")
plt.show()

# %%
print(w_s)
# Out:
# [  1.17146586   2.34293171   3.51439757   4.68586342   5.85732928
#    7.02879514   8.20026099   9.37172685  10.5431927   11.71465856
#   12.88612441  14.05759027  15.22905613  16.40052198  17.57198784
#   18.74345369  19.91491955  21.08638541  22.25785126  23.42931712
#   24.60078297  25.77224883  26.94371468  28.11518054  29.2866464
#   30.45811225  31.62957811  32.80104396  33.97250982  35.14397568
#   36.31544153  37.48690739  38.65837324  39.8298391   41.00130495
#   42.17277081  43.34423667  44.51570252  45.68716838  46.85863423
#   48.03010009  49.20156595  50.3730318   51.54449766  52.71596351
#   53.88742937  55.05889522  56.23036108  57.40182694  58.57329279
#   59.74475865  60.9162245   62.08769036  63.25915622  64.43062207
#   65.60208793  66.77355378  67.94501964  69.1164855   70.28795135
#   71.45941721  72.63088306  73.80234892  74.97381477  76.14528063
#   77.31674649  78.48821234  79.6596782   80.83114405  82.00260991
#   83.17407577  84.34554162  85.51700748  86.68847333  87.85993919
#   89.03140504  90.2028709   91.37433676  92.54580261  93.71726847
#   94.88873432  96.06020018  97.23166604  98.40313189  99.57459775
#  100.7460636  101.91752946 103.08899531 104.26046117 105.43192703
#  106.60339288 107.77485874 108.94632459 110.11779045 111.28925631
#  112.46072216 113.63218802 114.80365387 115.97511973 117.14658558]

# %%
plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: J vs Central Spin")
ax.set_ylabel(r"J [$g\,cm^2/sec$]")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,J_s,'r--',label="SLy EoS")
plt.plot(w,J_f,'b--',label="FPS EoS")
plt.plot(w,J_a,'g--',label="APR EoS")
plt.text(60,0.2e47,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("Jvsw_SRot.png")
plt.show()

# %%
plt.figure()
ax=plt.gca()
ax.set_title(r"Slow Rotating NS Plot: Observed vs Central Spin")
ax.set_ylabel(r"$\Omega_{obs}$ [$rot/sec$]")
ax.set_xlabel(r"$\omega_0$ [$rot/sec$]")
plt.plot(w,w_s,'r--',label="SLy EoS")
plt.plot(w,w_f,'b--',label="FPS EoS")
plt.plot(w,w_a,'g--',label="APR EoS")
plt.text(60,20,r"$\rho_c = 10^{15}\;g/cm^3$",bbox=dict(facecolor='white', alpha=0.5))
plt.legend(loc="best")
plt.savefig("wvsw_SRot.png")
plt.show()
